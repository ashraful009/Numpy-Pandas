# %% [markdown]
# # creating numpy / n-d arrays

# %%
import numpy as np

# %%
array1 = np.array([1, 2, 3, 4, 5])

# %%
array1
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
arr2 = np.array([[1,2,3], [3,4,5]])
arr2
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
type(arr2)
# Out:
# numpy.ndarray
